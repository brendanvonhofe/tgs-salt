# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import os

# %%
PATH = Path("/home/bread/data/salt")
IMAGES = PATH/'images'
MASKS = PATH/'masks'
TEST = PATH/'test'

# %%
fns = os.listdir(IMAGES)
test_fns = os.listdir(TEST)
fn = fns[0]

# %% [markdown]
# # Script to reflect pad images

# %%
IMAGES128 = PATH/'images128'
MASKS128 = PATH/'masks128'
TEST128 = PATH/'test128'

# ctr = 0
# for filename in fns:
#     ctr += 1
#     if(ctr % 1000 == 0):
#         print(ctr)
#     abs_path = IMAGES/filename
#     im = plt.imread(str(abs_path))
#     im_128 = np.pad(im, ((0,27), (0,27), (0,0)), mode='reflect')
#     plt.imsave(str(IMAGES128/filename), im_128)

# %% [markdown]
# # Matplotlib to view images and their masks

# %%
im = plt.imread(str(IMAGES/fn))
mask = plt.imread(str(MASKS/fn))

# %%
plt.imshow(mask)

# %%
plt.imshow(np.pad(mask, ((0,27), (0,27)), mode='reflect'))

# %%
plt.imshow(im)

# %%
plt.imshow(np.pad(im, ((0,27), (0,27), (0,0)), mode='reflect'))

# %%
m = np.expand_dims(mask, axis=2)
masked_im = np.concatenate((im, m), axis=2)

# %%
plt.imshow(masked_im)

# %%
plt.imshow(np.pad(masked_im, ((0,27), (0,27), (0,0)), mode='reflect'))

# %%
masked_im.shape
# Out:
# (101, 101, 4)
